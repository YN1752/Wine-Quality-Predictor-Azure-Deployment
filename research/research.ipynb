# %%
dict = {"key1":"val1", "key2":"val2"}

# %%
dict["key1"]
# Out:
# 'val1'

# %%
from box import ConfigBox

# %%
## ConfigBox working
dict = ConfigBox(dict)

# %%
dict.key1
# Out:
# 'val1'

# %%
## Explanation for ensure_annotation
def prod(x:int, y:int) -> int:
    return x*y

# %%
prod(2,3)
# Out:
# 6

# %%
prod(3,"6")
# Out:
# '666'

# %%
from ensure import ensure_annotations

@ensure_annotations
def prod(x:int, y:int) -> int:
    return x*y

# %%
prod(3,"4")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 prod(3,"4")
#
# File c:\Users\ynaya\OneDrive\Documents\MLOps\datascienceproject\venv\lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function prod at 0x000001A32B5CB1C0> does not match annotation type <class 'int'>
